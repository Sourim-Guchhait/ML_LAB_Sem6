# %%
#python implimentation of agglomerative hierarchical clustering 
#steps of the implementation:

# 1. Data Pre-processing
# 2. Finding the optimal number of clusters using the Dendrogram
# 3. Training the hierarchical clustering model
# 4. Visualizing the clusters

# %%
#Data preprocessing steps
#importing the libraries
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd
#importing the dataset
dataset=pd.read_csv("C:/Users/SOURIM GUCHHAIT/my_data.csv")
x=dataset.iloc[:,[3,4]].values
dataset
# Out:
#      User_ID Gender   Age   Salary   Purchased
# 0   15624510    Male    28    19000          0
# 1   15810944    Male    35    20000          0
# 2   15668575  Female    28    43000          0
# 3   15243422  Female    29    57000          1
# 4   15804002    Male    19    76000          0
# 5   15728773    Male    33    58000          0
# 6   15423242  Female    27    84000          1
# 7   15694829  Female    32   150000          1
# 8   15600575    Male    24    33000          0
# 9   15727311  Female    35    65000          0
# 10  15570769  Female    26    80000          0
# 11  15606274  Female    30    52000          0
# 12  15746139    Male    20    86000          0
# 13  15704987    Male    32    18000          0
# 14  15628972    Male    42    82000          0
# 15  15697686    Male    29    80000          0
# 16  15733883    Male    47    25000          1
# 17  15617482    Male    45    26000          1
# 18  15704583    Male    46    28000          1
# ...

# %%
#finding the optimal number of clusters using the dendogram
import scipy.cluster.hierarchy as shc
dendro = shc.dendrogram(shc.linkage(x,method="ward"))
mtp.title("dendrogrma plot")
mtp.ylabel("euclidean plot")
mtp.xlabel("customers")
mtp.show()

# %%
# trainning the hierarchical model on dataset
from sklearn.cluster import AgglomerativeClustering 

hc=AgglomerativeClustering(n_clusters=5,metric='euclidean',linkage='ward')
y_pred=hc.fit_predict(x)
y_pred
# Out:
# array([4, 4, 0, 1, 3, 1, 3, 2, 0, 1, 3, 1, 3, 4, 3, 3, 0, 0, 0, 0, 4, 1,
#        0, 0, 1, 2, 4, 0, 4, 1, 4, 3, 0, 0], dtype=int64)

# %%
#visulaizing the clustres
mtp.scatter(x[y_pred ==0,0],x[y_pred==0,1],s=100,c='blue',label='cluster 1')

mtp.scatter(x[y_pred ==1,0],x[y_pred==1,1],s=100,c='green',label='cluster 2')

mtp.scatter(x[y_pred ==2,0],x[y_pred==2,1],s=100,c='red',label='cluster 3')

mtp.scatter(x[y_pred ==3,0],x[y_pred==3,1],s=100,c='cyan',label='cluster 4')

mtp.scatter(x[y_pred ==4,0],x[y_pred==4,1],s=100,c='magenta',label='cluster 5')

mtp.title('clustering of customers ')
mtp.xlabel('annual income (k$)')
mtp.ylabel('spending score(1-100)')
mtp.legend()
mtp.show()
